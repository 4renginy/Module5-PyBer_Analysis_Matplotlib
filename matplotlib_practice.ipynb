# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
#Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis,marker="*",color="blue", linewidth= 2 , label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label="Boston")
plt.xlabel("date")
plt.ylabel("Fare($)")
plt.ylim(0,45)
plt.title("PyBer Fare Month")
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
#Create the plot
plt.bar(x_axis, y_axis, color= "green", label="Boston")
#Create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare(S)")
#Create a tutke
plt.title("PyBer Fare by Month")
plt.legend()

# %%
#Create the plot
plt.barh(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.barh(x_axis,y_axis, color="magenta", label="Boston")
plt.gca().invert_yaxis()
plt.ylabel("Date")
plt.xlabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#Create the plot
plt.bar(x_axis,y_axis, color="green", label="Boston")
#Crate label for x and y axes
plt.xlabel("Data")
plt.ylabel("Fare($)")
#Create title
plt.title("PyBer Fare by Month")
plt.legend()

# %%
#Create the plot
plt.barh(x_axis,y_axis)
plt.gca().invert_yaxis()

# %%
#5.1.5
plt.barh(x_axis,y_axis, color="magenta", label="Boston")
plt.gca().invert_yaxis()
plt.ylabel("Data")
plt.xlabel ("Fare($)")
plt.title ("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
# 5.1.6 Create bar Charts with object oriented approach
#Create the plot with ax.plt() vertical bar chart
fig, ax=plt.subplots()
ax.bar(x_axis, y_axis, color="black", label='New York')
# Out:
# <BarContainer object of 12 artists>

# %%
#Create horizantal bar chart
fig, ax=plt.subplots()
ax.barh(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
fig,ax=plt.subplots()
ax.barh(y_axis,x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax=plt.subplots()
ax.barh(x_axis,y_axis, color="cyan", label="Chicago")
ax.invert_yaxis()
ax.set_xlabel("Fare($)")
ax.set_ylabel("Data")
ax.set_title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.scatter(y_axis,x_axis, color="red", label="Chicago")
plt.xlabel("Total Number of rides(Per City)")
plt.ylabel("Average Fare($)")
plt.gca().invert_yaxis()
plt.title("Average Fare vs Total Rides")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger=[]
for data in y_axis:
    y_axis_larger.append(data*3)
plt.scatter(x_axis,y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis,y_axis, s=[i*3 for i in y_axis], color="red", label="Chicago")
plt.xlabel("Total Number of rides(Per City)")
plt.ylabel("Average Fare($)")
plt.title("Average Fare vs Total Rides")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis,color="blue", s=[i*5for i in y_axis], legend()="Boston")
ax.set.title(sdlfkasdklf)
# Out:
#   File "<ipython-input-40-41c507cee3ac>", line 2
#     ax.scatter(x_axis, y_axis,color="blue", s=[i*5for i in y_axis], legend()="Boston")
#                                                                     ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
